# %%
#Criação de Base de dados Mysql
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Float, String

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="cussueca2018"
)

# Create a MySQL cursor
mycursor = mydb.cursor()

try:
    mycursor.execute("CREATE DATABASE IF NOT EXISTS hotel_bookings")
except:
    pass

# Switch to the 'hotel_bookings' database
mycursor.execute("USE hotel_bookings")

print("Database 'hotel_bookings' created successfully!")
# Out:
# Database 'hotel_bookings' created successfully!

# %%
import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="cussueca2018"
)

mycursor = mydb.cursor()
mycursor.execute("USE hotel_bookings")

# Create the 'rooms' table
mycursor.execute("""
CREATE TABLE Main_Info (
    id_reservation INT AUTO_INCREMENT PRIMARY KEY,
    hotel VARCHAR(255),
    lead_time INT,
    arrival_date_year INT,
    arrival_date_month INT,
    arrival_date_week_number INT,
    arrival_date_day_of_month INT,
    country VARCHAR(255),
    market_segment VARCHAR(255),
    distribution_channel VARCHAR(255),
    is_repeated_guest INT,
    booking_changes INT,
    days_in_waiting_list INT,
    company VARCHAR(255),
    customer_type VARCHAR(255),
    reservation_status_date DATE
);

""")

# Create the 'bookings' table
mycursor.execute("""
CREATE TABLE Reservas_Status (
    id_reservation INT,
    is_cancelled INT,
    arrival_date_year INT,
    arrival_date_month INT,
    angent VARCHAR(255),
    previous_cancellations INT,
    previous_bookings_not_cancelled INT,
    country VARCHAR(255),
    deposit_type VARCHAR(255),
    reservation_status VARCHAR(255),
    PRIMARY KEY (id_reservation),
    FOREIGN KEY (id_reservation) REFERENCES Main_Info(id_reservation)
);

""")

# Create the 'guests' table
mycursor.execute("""
CREATE TABLE Stays_Info (
    id_reservation INT,
    stays_in_week_nights INT,
    stays_in_weekends_nights INT,
    adult INT,
    children INT,
    babies INT,
    required_car_parking_spaces INT,
    meal VARCHAR(255),
    reserved_room_type VARCHAR(255),
    total_of_special_requests INT,
    PRIMARY KEY (id_reservation),
    FOREIGN KEY (id_reservation) REFERENCES Main_Info(id_reservation)
);

""")

# Commit the changes to the database
mydb.commit()
print("Database 'Table Main_Info, Reservas_Status, Stays_Info ' created successfully!")
# Close the connection to the database
mydb.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[7], line 12
#       9 mycursor.execute("USE hotel_bookings")
#      11 # Create the 'rooms' table
# ---> 12 mycursor.execute("""
#      13 CREATE TABLE Main_Info (
#      14     id_reservation INT AUTO_INCREMENT PRIMARY KEY,
#      15     hotel VARCHAR(255),
#      16     lead_time INT,
#      17     arrival_date_year INT,
#      18     arrival_date_month INT,
#      19     arrival_date_week_number INT,
#      20     arrival_date_day_of_month INT,
#      21     country VARCHAR(255),
#      22     market_segment VARCHAR(255),
#      23     distribution_channel VARCHAR(255),
#      24     is_repeated_guest INT,
#      25     booking_changes INT,
#      26     days_in_waiting_list INT,
#      27     company VARCHAR(255),
#      28     customer_type VARCHAR(255),
#      29     reservation_status_date DATE
#      30 );
# ...

# %%
#Inserção de dados manualmente

import mysql.connector
import pandas as pd
from sqlalchemy import create_engine

# Establish a connection to the MySQL database
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="cussueca2018",
    database="hotel_bookings"
)

# Create a MySQL cursor
mycursor = mydb.cursor()

# Insert data into the 'Main_Info' table
main_info_insert_query = """
INSERT INTO Main_Info (
    hotel, lead_time, arrival_date_year, arrival_date_month,
    arrival_date_week_number, arrival_date_day_of_month,
    country, market_segment, distribution_channel,
    is_repeated_guest, booking_changes, days_in_waiting_list,
    company, customer_type, reservation_status_date
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Insert data into the 'Reservas_Status' table
reservas_status_insert_query = """
INSERT INTO Reservas_Status (
    id_reservation, is_cancelled, arrival_date_year,
    arrival_date_month, angent, previous_cancellations,
    previous_bookings_not_cancelled, country, deposit_type,
    reservation_status
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Insert data into the 'Stays_Info' table
stays_info_insert_query = """
INSERT INTO Stays_Info (
    id_reservation, stays_in_week_nights,
    stays_in_weekends_nights, adult, children, babies,
    required_car_parking_spaces, meal, reserved_room_type,
    total_of_special_requests
) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# Iterate through rows and insert into tables
for index, row in df.iterrows():
    try:
        # Insert into Main_Info table
        mycursor.execute(main_info_insert_query, tuple(row))
        
        # Insert into Reservas_Status table
        mycursor.execute(reservas_status_insert_query, tuple(row))

        # Insert into Stays_Info table
        mycursor.execute(stays_info_insert_query, tuple(row))
        
        print(f"Inserted row {index + 1} successfully.")
    except mysql.connector.Error as err:
        if err.errno == 1062:  # Duplicate entry error
            print(f"Duplicate entry for row {index + 1}. Skipping.")
        else:
            print(f"Error: {err}")

# Commit the changes to the database
mydb.commit()

# Close the connection to the database
mydb.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 8
#       5 from sqlalchemy import create_engine
#       7 # Load the CSV data into a DataFrame
# ----> 8 df = pd.read_csv('path/to/your/dataset.csv')
#      10 # Establish a connection to the MySQL database
#      11 mydb = mysql.connector.connect(
#      12     host="localhost",
#      13     user="root",
#      14     password="cussueca2018",
#      15     database="hotel_bookings"
#      16 )
#
# ...

# %%
#Insert de dados no mysql usando o ficheiro csv 
import pandas as pd
from sqlalchemy import create_engine

# Carrega os dados CSV em DataFrame
df = pd.read_csv('path/to/your/dataset.csv')

# Estabeleça uma conexão com o banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')

#Inserir dados na base de dados
try:
    with engine.begin() as connection:
        df.to_sql('Main_Info', con=connection, if_exists='append', index=False)
        df.to_sql('Reservas_Status', con=connection, if_exists='append', index=False)
        df.to_sql('Stays_Info', con=connection, if_exists='append', index=False)
        
#if_exists: Este parâmetro determina o que fazer se a tabela já existir no banco de dados. Ele aceita três valores principais:
#'fail': Gera um ValueError se a tabela existir.
#'replace': Substitui a tabela existente se ela já existir. Isso significa que ele irá apagar a tabela atual e criar uma nova com os mesmos dados.
#'append': Adiciona os novos dados à tabela existente. Isso é útil quando você deseja adicionar mais dados a uma tabela existente sem excluir ou substituir a tabela atual.
    
    print("Data inserted successfully.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 from sqlalchemy import create_engine
#       4 # Load the CSV data into a DataFrame
# ----> 5 df = pd.read_csv('path/to/your/dataset.csv')
#       7 # Establish a connection to the MySQL database using SQLAlchemy
#       8 engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')
#
# ...

# %%
#CRIANDO CONSULTAS SIMPLES EM DUAS TABELAS
#(1) - Consulta para selecionar dados da tabela Main_Info
import pandas as pd
from sqlalchemy import create_engine

# Estabeleça uma conexão ao banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')

# Consulta para selecionar uma coluna específica
sqlConsult = "SELECT * FROM Main_Info"

# Execute a consulta e armazene o resultado em um DataFrame
dfSql = pd.read_sql(sqlConsult, con=engine)

# Exiba o DataFrame resultante
print(dfSql)

#(2)
# Consulta para selecionar dados da tabela Reservas_Status
sqlConsult1 = "SELECT * FROM Reservas_Status"

# Execução da consulta e armazenamneto do resultado em um DataFrame
dfSql1 = pd.read_sql(sqlConsult1, con=engine)

# Exiba o DataFrame resultante
print(dfSql1)
# Out:
# Empty DataFrame
# Columns: [id_reservation, hotel, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, country, market_segment, distribution_channel, is_repeated_guest, booking_changes, days_in_waiting_list, company, customer_type, reservation_status_date]
# Index: []
# Empty DataFrame
# Columns: [id_reservation, is_cancelled, arrival_date_year, arrival_date_month, angent, previous_cancellations, previous_bookings_not_cancelled, country, deposit_type, reservation_status]
# Index: []

# %%
# Duas consultas complexas, usando junções e agregações, envolvendo pelo menos
#(1) Esta consulta de agregação calcula a média do número de estadias na tabela

import pandas as pd
from sqlalchemy import create_engine

# Estabeleça uma conexão ao banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')

# Consulta com junção e agregação
sqlagregacao = """
    SELECT Main_Info.hotel, AVG(Stays_Info.stays_total) as avg_stays_total
    FROM Main_Info
    INNER JOIN Stays_Info ON Main_Info.id_reservation = Stays_Info.id_reservation
    GROUP BY Main_Info.hotel
"""

# Execute a consulta e armazene o resultado em um DataFrame
df_agregacao = pd.read_sql(sqlagregacao, con=engine)

# Exiba o resultado do DataFrame
print(df_agregacao)


#(2) - Esta consulta de agregação conta o número total de reservas não canceladas
# Consulta com junção, filtro e agregação
Sql_rn_canceladas = """
    SELECT Main_Info.country, COUNT(*) as total_reservas_nao_canceladas
    FROM Main_Info
    INNER JOIN Reservas_Status ON Main_Info.id_reservation = Reservas_Status.id_reservation
    WHERE Reservas_Status.is_cancelled = 0
    GROUP BY Main_Info.country
"""

# Execute a consulta do  DataFrame rnc-reservas nao canceladas
df_rnc_n1 = pd.read_sql(Sql_rn_canceladas, con=engine)

# Exiba o DataFrame resultante
print(df_rnc)

# %%
#ATUALIZAÇÃO DE DADOS
import pandas as pd
from sqlalchemy import create_engine

# Estabeleça uma conexão ao banco de dados MySQL usando SQLAlchemy
engine = create_engine('mysql+mysqlconnector://root:cussueca2018@localhost/hotel_bookings')

# Novo valor para a coluna lead_time
novo_lead_time = 90

# Consulta de atualização
Sql_atualizacao = f"""
    UPDATE Main_Info
    SET lead_time = {novo_lead_time}
    WHERE lead_time > 100
"""
# Execute a consulta de atualização
with engine.begin() as connection:
    connection.execute(Sql_atualizacao)

print("Atualização concluída com sucesso.")

# %%
#Criação da base de dados e collections índices no MongoDB
import pymongo
from pymongo import MongoClient
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship
from pymongo.errors import DuplicateKeyError

# Connect to MongoDB
client = MongoClient('localhost', 27017)
db = client.hotel_bookings

# Define the Main_Info collection
main_info_collection = db['Main_Info']

# Criar um índice único em 'campo_unico' na coleção 'Main_Info'
main_info_collection.create_index([("id_reservation", pymongo.ASCENDING)], unique=True)

# Define the Reservas_Status collection
reservas_status_collection = db['Reservas_Status']

# Criar índices únicos em 'campo_unico_1' e 'campo_unico_2' na coleção 'Reservas_Status'
reservas_status_collection.create_index([("id_reservation", pymongo.ASCENDING)], unique=True)

# Define the Stays_Info collection
stays_info_collection = db['Stays_Info']

# Criar um índice único em 'campo_unico' na coleção 'Stays_Info'
stays_info_collection.create_index([("id_reservation", pymongo.ASCENDING)], unique=True)

print("Coleções criadas com sucesso e índices únicos aplicados!")
# Out:
# Coleções criadas com sucesso e índices únicos aplicados!

# %%
#Inser dados na base de dados do MongoDB usando dataset.csv
import pandas as pd
from pymongo.errors import DuplicateKeyError

client = MongoClient('localhost', 27017)
db = client.hotel_bookings

# Ler o arquivo CSV em um DataFrame do pandas
Dados_csv = 'hotel_bookings.csv'  
df = pd.read_csv(Dados_csv)

# Inserindo cada linha nas coleções do MongoDB
for index, row in df.iterrows():
    Main_Info = {
        "id_reservation": row['id_reservation'],
        "hotel": row['hotel'],
        "lead_time": row['lead_time'],
        "arrival_date_year": row['arrival_date_year'],
        "arrival_date_month": row['arrival_date_month'],
        "arrival_date_week_number": row['arrival_date_week_number'],
        "arrival_date_day_of_month": row['arrival_date_day_of_month'],
        "country": row['country'],
        "market_segment": row['market_segment'],
        "distribution_channel": row['distribution_channel'],
        "is_repeated_guest": row['is_repeated_guest'],
        "booking_changes": row['booking_changes'],
        "days_in_waiting_list": row['days_in_waiting_list'],
        "company": row['company'],
        "customer_type": row['customer_type'],
        "reservation_status_date": row['reservation_status_date'],
    }
    
    Reservas_Status = {
        "id_reservation": row['id_reservation'],
        "is_cancelled": row['is_cancelled'],
        "arrival_date_year": row['arrival_date_year'],
        "arrival_date_month": row['arrival_date_month'],
        "agent": row['agent'],
        "previous_cancellations": row['previous_cancellations'],
        "previous_bookings_not_cancelled": row['previous_bookings_not_cancelled'],
        "country": row['country'],
        "deposit_type": row['deposit_type'],
        "reservation_status": row['reservation_status'],
    }
    
    Stays_Info = {
       "id_reservation": row['id_reservation'],
        "stays_in_week_nights": row['stays_in_week_nights'],
        "stays_in_weekends_nights": row['stays_in_weekends_nights'],
        "adult": row['adult'],
        "children": row['children'],
        "babies": row['babies'],
        "required_car_parking_spaces": row['required_car_parking_spaces'],
        "meal": row['meal'],
        "reserved_room_type": row['reserved_room_type'],
        "total_of_special_requests": row['total_of_special_requests'],
    }
    #tratamento de erros e inserção de dados nas collections
    try:
        main_info_collection.insert_one(Main_Info)
        reservas_status_collection.insert_one(Reservas_Status)
        stays_info_collection.insert_one(Stays_Info)
        print(f"Dados para id_reservation {row['id_reservation']} inseridos com sucesso.")
    except DuplicateKeyError:
        print(f"Erro de chave duplicada para id_reservation {row['id_reservation']}. Pulando a inserção.")

print("Inserção de dados concluída.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 10
#       8 # Ler o arquivo CSV em um DataFrame do pandas
#       9 Dados_csv = 'hotel_bookings.csv'
# ---> 10 df = pd.read_csv(Dados_csv)
#      12 # Inserindo cada linha nas coleções do MongoDB
#      13 for index, row in df.iterrows():
#
# ...

# %%
#Duas consultas simples, selecionando dados de uma ou duas colunas/campos (3)
import pymongo
# (1) - Consulta em Main_Info
# Consulta para selecionar dados da coluna 'hotel' em Main_Info
MDB_main_info = main_info_collection.find({}, {"hotel": 1})

# Verificar se a consulta retornou algum resultado
if main_info_collection.count_documents({}) > 0:
    # Display the results of the query
    for resultInfo in MDB_main_info:
        print(resultInfo)
else:
    print("Não há documentos para serem exibidos em Main_Info.")

# (2) - Consulta em Reservas_Status
# Consulta para selecionar dados das colunas 'id_reservation' e 'is_cancelled' em Reservas_Status
MDB_reservas_status = reservas_status_collection.find({}, {"id_reservation": 1, "is_cancelled": 1})

# Verificar se a consulta retornou algum resultado
if reservas_status_collection.count_documents({}) > 0:
    # Display the results of the query
    for resultReservas in MDB_reservas_status:
        print(resultReservas)
else:
    print("Não há documentos para serem exibidos em Reservas_Status.")
# Out:
# {'_id': ObjectId('6559b033bf9275d764a4f30b'), 'hotel': 'Novo Hotel'}
# Não há documentos para serem exibidos em Reservas_Status.

# %%
#Duas consultas complexas, usando junções e agregações, envolvendo pelo menos(3)
#(1) - Fornece o tempo médio de antecedência para reservas que não foram canceladas, agrupadas por hotel.
import pymongo
pipeline = [
    {
        "$match": {
            "Reservas_Status.is_cancelled": {"$ne": 1}  # Filtra reserva cancelada
        }
    },
    {
        "$group": {
            "_id": "$Main_Info.hotel",
            "average_lead_time": {"$avg": "$Main_Info.lead_time"}
        }
    }
]

result = db.Main_Info.aggregate(pipeline)

for doc in result:
    print(f"Hotel: {doc['_id']}, Average Lead Time: {doc['average_lead_time']}")

#(2) - Fornece o número total de reservas para cada país e mês
pipeline = [
    {
        "$group": {
            "_id": {
                "country": "$Main_Info.country",
                "month": "$Main_Info.arrival_date_month"
            },
            "total_reservations": {"$sum": 1}
        }
    },
    {
        "$sort": {"_id.country": 1, "_id.month": 1}
    }
]

result1 = db.Main_Info.aggregate(pipeline)

for doc1 in result1:
    print(f"Country: {doc1['_id']['country']}, Month: {doc1['_id']['month']}, Total Reservations: {doc1['total_reservations']}")

# %%
#Actualizar um determinaddo dado na tabela
from pymongo import MongoClient

# Conectar ao banco de dados
client = MongoClient('localhost', 27017)
db = client.hotel_bookings

# Atualizar o campo 'is_repeated_guest' para True onde 'id_reservation' é igual a algum valor específico
filter_condition = {"Main_Info.id_reservation": 2}
update_data = {"$set": {"Main_Info.is_repeated_guest": True}}

result = db.Main_Info.update_one(filter_condition, update_data)

print(f"Total de documentos correspondentes: {result.matched_count}")
print(f"Total de documentos modificados: {result.modified_count}")
# Out:
# Total de documentos correspondentes: 0
# Total de documentos modificados: 0

# %%
#Inserir um novo documento
from pymongo import MongoClient
from datetime import datetime

# Conectar ao banco de dados
client = MongoClient('localhost', 27017)
db = client.hotel_bookings

# Novo documento a ser inserido
novo_documento = {
    "id_reservation": 9999,
    "hotel": "Novo Hotel",
    "lead_time": 30,
    "arrival_date_year": 2023,
    "arrival_date_month": "Novembro",
    "arrival_date_week_number": 47,
    "arrival_date_day_of_month": 15,  # Substitua pelo valor desejado
    "country": "Portugal",
    "market_segment": 45,
    "distribution_channel": 478,
    "is_repeated_guest": 422,
    "booking_changes": 788,
    "days_in_waiting_list": 410,
    "company": "Tap",
    "customer_type": 6521,
    "reservation_status_date": datetime(2023, 11, 19)  # Utilize um objeto datetime
}

# Inserir o novo documento na coleção
result = db.Main_Info.insert_one(novo_documento)

# Verificar se a inserção foi bem-sucedida
if result.inserted_id:
    print(f"Novo documento inserido com sucesso. ID: {result.inserted_id}")
else:
    print("Falha ao inserir o documento.")
# Out:
# Novo documento inserido com sucesso. ID: 6559b033bf9275d764a4f30b

# %%
#INSER ATRAVEZ DOS DADOS VINDOS DO MYSQL
import mysql.connector
import pandas as pd
import pymongo
from pymongo import MongoClient
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship

# Conectar-se ao MySQL
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="cussueca2018",
    database="siaga"  # Substitua pelo nome do seu banco de dados
)


# Verificar se a conexão foi bem-sucedida
if mydb.is_connected():
    print("A conexão ao MySQL foi estabelecida com êxito!")

# Consulta SQL para obter os dados desejados
sql_query = "SELECT * FROM Main_Info"
df_mysql = pd.read_sql(sql_query, mydb)

# Conectar-se ao MongoDB
mongo_client = MongoClient('localhost', 27017)
mongo_db = mongo_client.hotel_bookings

# Converter DataFrame do Pandas para dicionário (orient='records')
dados_para_inserir = df_mysql.to_dict(orient='records')

# Selecionar a coleção no MongoDB
colecao_mongodb = mongo_db.Main_Info

# Inserir os dados no MongoDB
for VD in dados_para_inserir:
    #Tratamento de erros
    try:
        colecao_mongodb.insert_one(VD)
        print("Documento inserido com êxito!")
    except DuplicateKeyError as e:
        print(f"Foram detetados documentos duplicados e ignorado:{e.details}")
# Out:
# Conexão ao MySQL estabelecida com sucesso!
# Foram detetados documentos duplicados e ignorado:{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: hotel_bookings.Main_Info index: id_reservation_1 dup key: { id_reservation: null }', 'keyPattern': {'id_reservation': 1}, 'keyValue': {'id_reservation': None}}
# Foram detetados documentos duplicados e ignorado:{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: hotel_bookings.Main_Info index: id_reservation_1 dup key: { id_reservation: null }', 'keyPattern': {'id_reservation': 1}, 'keyValue': {'id_reservation': None}}
# Foram detetados documentos duplicados e ignorado:{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: hotel_bookings.Main_Info index: id_reservation_1 dup key: { id_reservation: null }', 'keyPattern': {'id_reservation': 1}, 'keyValue': {'id_reservation': None}}
# ...

# %%
if mydb.is_connected():
    print("A conexão ao MySQL foi estabelecida com êxito!")

# Consulta SQL para obter os dados desejados
sql_query = "SELECT * FROM Reservas_Status"
df_mysql = pd.read_sql(sql_query, mydb)

# Conectar-se ao MongoDB
mongo_client = MongoClient('localhost', 27017)
mongo_db = mongo_client.hotel_bookings

# Converter DataFrame do Pandas para dicionário (orient='records')
dados_para_inserir = df_mysql.to_dict(orient='records')

# Selecionar a coleção no MongoDB
colecao_mongodb = mongo_db.Reservas_Status

# Inserir os dados no MongoDB
for VD in dados_para_inserir:
    #Tratamento de erros
    try:
        colecao_mongodb.insert_one(VD)
        print("Documento inserido com êxito!")
    except DuplicateKeyError as e:
        print(f"Foram detetados documentos duplicados e ignorado:{e.details}")
# Out:
# Conexão ao MySQL estabelecida com sucesso!
# Foram detetados documentos duplicados e ignorado:{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: hotel_bookings.Reservas_Status index: id_reservation_1 dup key: { id_reservation: null }', 'keyPattern': {'id_reservation': 1}, 'keyValue': {'id_reservation': None}}
# Foram detetados documentos duplicados e ignorado:{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: hotel_bookings.Reservas_Status index: id_reservation_1 dup key: { id_reservation: null }', 'keyPattern': {'id_reservation': 1}, 'keyValue': {'id_reservation': None}}
# Foram detetados documentos duplicados e ignorado:{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: hotel_bookings.Reservas_Status index: id_reservation_1 dup key: { id_reservation: null }', 'keyPattern': {'id_reservation': 1}, 'keyValue': {'id_reservation': None}}
# ...

# %%
if mydb.is_connected():
    print("A conexão ao MySQL foi estabelecida com êxito!")

# Consulta SQL para obter os dados desejados
sql_query = "SELECT * FROM Stays_Info"
df_mysql = pd.read_sql(sql_query, mydb)

# Conectar-se ao MongoDB
mongo_client = MongoClient('localhost', 27017)
mongo_db = mongo_client.hotel_bookings

# Converter DataFrame do Pandas para dicionário (orient='records')
dados_para_inserir = df_mysql.to_dict(orient='records')

# Selecionar a coleção no MongoDB
colecao_mongodb = mongo_db.Stays_Info

# Inserir os dados no MongoDB

for VD in dados_para_inserir:
    #Tratamento de erros
    try:
        colecao_mongodb.insert_one(VD)
        print("Documento inserido com êxito!")
    except DuplicateKeyError as e:
        print(f"Foram detetados documentos duplicados e ignorado:{e.details}")
# Out:
# Conexão ao MySQL estabelecida com sucesso!
# Foram detetados documentos duplicados e ignorado:{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: hotel_bookings.Stays_Info index: id_reservation_1 dup key: { id_reservation: null }', 'keyPattern': {'id_reservation': 1}, 'keyValue': {'id_reservation': None}}
# Foram detetados documentos duplicados e ignorado:{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: hotel_bookings.Stays_Info index: id_reservation_1 dup key: { id_reservation: null }', 'keyPattern': {'id_reservation': 1}, 'keyValue': {'id_reservation': None}}
# Foram detetados documentos duplicados e ignorado:{'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: hotel_bookings.Stays_Info index: id_reservation_1 dup key: { id_reservation: null }', 'keyPattern': {'id_reservation': 1}, 'keyValue': {'id_reservation': None}}
# ...

# %%
#4-CRIAÇÃO DE INDICES
import mysql.connector

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="cussueca2018"
)

mycursor = mydb.cursor()

# Índice para a tabela Main_Info
mycursor.execute("CREATE INDEX idx_hotel ON Main_Info(hotel)")

# Índice para a tabela Reservas_Status
mycursor.execute("CREATE INDEX idx_country ON Reservas_Status(country)")

# Índice para a tabela Stays_Info
mycursor.execute("CREATE INDEX idx_reserved_room_type ON Stays_Info(reserved_room_type)")

# Confirmar as alterações no banco de dados
mydb.commit()
print("Índices criados com sucesso!")

# Fechar a conexão com o banco de dados
mydb.close()
